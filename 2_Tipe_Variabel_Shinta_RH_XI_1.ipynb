# %% [markdown]
# <a href="https://colab.research.google.com/github/alfiana3215773-sudo/alfiana3215773-gmail.com/blob/main/2_Tipe_Variabel_Shinta_RH_XI_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Shinta Roudlotul Hanafia
#
# Kelas: XI.1
#
# No. absen: 29

# %% [markdown]
# #Konsep Dasar

# %%
email_user_1 = "shintahanafia.2025@gmail.com"

print(email_user_1)
# Out:
# shintahanafia.2025@gmail.com

# %%
sabun_lifebuoy = 15000

print(sabun_lifebuoy)
# Out:
# 15000

# %%
print(sabun_lifebuoy*5)
# Out:
# 75000

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
# Penulisan variabel hanya boleh menggunakan huruf, angka dan underscore
# Tidak boleh menggunakan spasi
nama siswa = "Afa"

print(nama siswa)
# Out:
#   File "/tmp/ipython-input-3799468047.py", line 3
#     nama siswa = "Afa"
#          ^
# SyntaxError: invalid syntax

# %%
#Tidak boleh diawali dengan angka

1_nama_siswa = "Afa"
print(1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-1201669175.py", line 3
#     1_nama_siswa = "Afa"
#      ^
# SyntaxError: invalid decimal literal

# %%
# Penulisan variabel itu case sensitive/sensitif capslock
nama_siswa_1 = "Afa"

print(Nama_siswa_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4033144184.py in <cell line: 0>()
#       2 nama_siswa_1 = "Afa"
#       3
# ----> 4 print(Nama_siswa_1)
#
# NameError: name 'Nama_siswa_1' is not defined

# %%
# Dilarang menggunakan kata kunci di Bahasa Python
prin = "Afa"

print(prin)
# Out:
# Afa

# %%
# Tidak boleh pakai kata kunci python, if, for, class, print, dll
# Kalau error akibat membuat nama variabel dengan kata kunci print, maka, harus disconnect dulu
# print = "Devin"

# print(print)

# %%
end = "Naufal"

print(end)
# Out:
# Naufal

# %%
#Tidak Deskriptif
_ = "Favian" # Bisa, tapi tidak jelas/tidak deskriptif

print(_)

#Seharusnya, yang deskriptif:

nama_pelanggan = "Faviana"
print(nama_pelanggan)
# Out:
# Favian
# Faviana

# %% [markdown]
# #Assignment

# %% [markdown]
# ##Single Assignment

# %%
nama_siswa_2 = "Dhapne"
nama_siswa_3 = "Farel"
print(nama_siswa_2)
print(nama_siswa_3)
# Out:
# Dhapne
# Farel

# %% [markdown]
# ##Multiple Assignement

# %%
nama_siswa_4, nama_siswa_5 = "Sada", "Selo"

print(nama_siswa_4)
print(nama_siswa_5)
# Out:
# Sada
# Selo

# %% [markdown]
# ##Chain Assignment

# %%
nilai_afa = nilai_favian = 100

print(nilai_afa)
print(nilai_favian)
# Out:
# 100
# 100

# %% [markdown]
# ##Perubahan Nilai Variabel

# %%
nilai_afa = 95
print(nilai_afa)
# Out:
# 95

# %% [markdown]
# #Cara Penggunaan Operator

# %%
#Tanpa disimpan dalam variabel
print(5000*3)
# Out:
# 15000

# %%
#Simpan operand ke dalam variabel
harga_kojek = 6000
banyak_porsi = 3

print(harga_kojek*banyak_porsi)
# Out:
# 18000

# %%
#Simpan hasil operasi ke dalam variabel
harga_total_kojek = 3000*3

print(harga_total_kojek)
# Out:
# 9000

# %%
#Simpan nilai operand dan hasil operasi ke dalam variabel
harga_cilok = 10000
jumlah_porsi_cilok = 5
harga_total_cilok = harga_cilok*jumlah_porsi_cilok

print(harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diterima = 100000
uang_kembalian = uang_yang_diterima - harga_total_cilok

print(uang_kembalian)
# Out:
# 50000

# %% [markdown]
# #Jenis-jenis Operator

# %% [markdown]
# ##Operator Aritmatika

# %%
uang_shinta = 200000
uang_favian = 500000
uang_total = uang_shinta + uang_favian

print(uang_total)
# Out:
# 700000

# %%
uang_customer = 300000
total_belanja = 250000
uang_kembalian = uang_customer - total_belanja

print(uang_kembalian)
# Out:
# 50000

# %%
harga_susu_kotak = 5000
jumlah_susu_kotak = 3
harga_susu_total = harga_susu_kotak*jumlah_susu_kotak

print(harga_susu_total)
# Out:
# 15000

# %%
banyak_roti = 20
jumlah_tamu = 7

roti_setiap_tamu = banyak_roti/jumlah_tamu

print(roti_setiap_tamu)
# Out:
# 2.857142857142857

# %%
banyak_roti = 20
jumlah_tamu = 7

roti_setiap_tamu = banyak_roti//jumlah_tamu

print(roti_setiap_tamu)
# Out:
# 2

# %%
banyak_roti = 20
jumlah_tamu = 7

sisa_roti = banyak_roti%jumlah_tamu

print(sisa_roti)
# Out:
# 6

# %%
sisi_persegi = 5
luas_persegi = sisi_persegi**2

print(luas_persegi)
# Out:
# 25

# %%
luas_persegi = 36
sisi_persegi = luas_persegi**0.5

print(sisi_persegi)
# Out:
# 6.0

# %% [markdown]
# #Tipe Variabel

# %%
usia = 65

type(usia)
# Out:
# int

# %%
berat_telur = 2.5

type(berat_telur)
# Out:
# float

# %%
nama = "Shinta"

type(nama)
# Out:
# str

# %%
remidi = False

type(remidi)
# Out:
# bool

# %%
remidi = True

type(remidi)
# Out:
# bool

# %%
koordinat_bintang = -1.5

type(koordinat_bintang)
# Out:
# float

# %%
koordinat_titik = -8
type(koordinat_titik)
# Out:
# int

# %% [markdown]
# #Input

# %%
panjang = 10
lebar = 5
luas = panjang*lebar

print(luas)
# Out:
# 50

# %%
input()
# Out:
# 10
# '10'

# %%
panjang = input()
# Out:
# 10

# %%
print(panjang)
# Out:
# 10

# %%
lebar = input()
# Out:
# 5

# %%
print(lebar)
# Out:
# 5

# %%
#Tipe data masih string dan harus di-convert ke integer/float
luas = panjang*lebar

print(luas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-508063834.py in <cell line: 0>()
# ----> 1 luas = panjang*lebar
#       2
#       3 print(luas)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
type(panjang)
# Out:
# str

# %%
type(lebar)
# Out:
# str

# %%
panjang = int(panjang)

# %%
lebar = int(lebar)

# %%
type(panjang)
# Out:
# int

# %%
panjang_1 = int(input("Masukkan panjang persegi: "))
# Out:
# Masukkan panjang persegi: 10

# %%
panjang_2 = int(input("Masukkan panjang persegi: "))
lebar_2 = int(input("Masukkan lebar persegi: "))

luas_2 = panjang_2*lebar_2

print(f"Luas persegi panjang adalah {luas_2} cm^2")
# Out:
# Masukkan panjang persegi: 4
# Masukkan lebar persegi: 10
# Luas persegi panjang adalah 40 cm^2

# %%
print("luas")
# Out:
# luas

# %%
input()
# Out:
# 5
# '5'

# %%
panjang = int(input("Masukkan panjang persegi (cm): "))
lebar = int(input("Masukkan lebar persegi (cm): "))

luas = panjang*lebar

print(f"Luas persegi adalah {luas} cm^2")
# Out:
# Masukkan panjang persegi (cm): 2
# Masukkan lebar persegi (cm): 3
# Luas persegi adalah 6 cm^2

# %%
panjang = int(input("Masukkan panjang persegi (m): "))
lebar = int(input("Masukkan lebar persegi (m): "))
tinggi = int(input("Masukkan tinggi persegi (m): "))

volume = panjang * lebar * tinggi

print(f"Volume balok adalah {volume} m^3")
# Out:
# Masukkan panjang persegi (m): 5
# Masukkan lebar persegi (m): 3
# Masukkan tinggi persegi (m): 1
# Volume balok adalah 15 m^3

# %%
panjang = float(input("Masukkan panjang persegi (m): "))
lebar = float(input("Masukkan lebar persegi (m): "))
tinggi = float(input("Masukkan tinggi persegi (m): "))

volume = panjang * lebar * tinggi

print(f"Volume balok adalah {volume} m^3")
# Out:
# Masukkan panjang persegi (m): 5
# Masukkan lebar persegi (m): 3
# Masukkan tinggi persegi (m): 1
# Volume balok adalah 15.0 m^3

# %% [markdown]
# #Konversi Tipe Data

# %%
a = 3
print(a)
type(a)
# Out:
# 3
# int

# %%
a = float(a)
print(a)
type(a)
# Out:
# 3.0
# float

# %%
a = str(a)
print(a)
type(a)
# Out:
# 3.0
# str

# %%
a = bool(a)
print(a)
type(a)
# Out:
# True
# bool

# %%
b = "cicak"
print(b)

b = bool(b)
print(b)
# Out:
# cicak
# True

# %%
c = ""
print(c)

c = bool(c)
print(c)
# Out:
# False

# %%
d = False
print(d)
type(d)
# Out:
# False
# bool

# %%
e = "False"
print(e)
type(e)
# Out:
# False
# str

# %% [markdown]
# #Operator Perbanding

# %%
print(8<5)
# Out:
# False

# %%
print(8>5)
# Out:
# True

# %%
print(9>=9)
# Out:
# True

# %%
print(8 == 5)
# Out:
# False

# %%
print( 8 == 8)
# Out:
# True

# %%
print(1 != 1)
# Out:
# False

# %%
a = 10
b = 20
c = 30

print(a>c)
# Out:
# False

# %%
print(a>30)
# Out:
# False

# %%
nilai_kka = 75
kkm_kka = 80

print(nilai_kka > kkm_kka)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(8>7 and 5>6)
# Out:
# False

# %%
print(8>7 and 5<6)
# Out:
# True

# %%
print(8>7 or 5>6)
# Out:
# True

# %%
print(not(8>7 or 5>6))
# Out:
# False

# %%
print(not (8>=9 or 9!=8))
# Out:
# False

# %%
iq_min = 125
tinggi_min = 165

print(125 >=iq_min and 170 >= tinggi_min)
# Out:
# True

# %%
iq_afa = 125
tinggi_afa = 170

print(iq_afa >= iq_min and tinggi_afa >= tinggi_min)
# Out:
# True
